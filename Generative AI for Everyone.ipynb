# %% [markdown]
# # What is Generative Ai ?
# ![image.png](attachment:44c45867-4b5c-4ead-a39a-dc07fccc2120.png)

# %% [markdown]
# ## What is RAG in LLM ?
#
# -

# %% [markdown]
# **Sources** : [Generative AI for Everyone](https://www.coursera.org/learn/generative-ai-for-everyone/)
